# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
berka = pd.read_csv("C:/Users/niafrate/OneDrive - Ryerson University/CIND820/finData.csv")

# %%
berka.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 674 entries, 0 to 673
# Data columns (total 20 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   account_id         674 non-null    int64
#  1   amount             674 non-null    int64
#  2   duration           674 non-null    int64
#  3   payments           674 non-null    int64
#  4   frequency          674 non-null    object
#  5   date_diff          674 non-null    int64
#  6   card_type          674 non-null    object
#  7   no_orders          674 non-null    int64
#  8   avg_order          674 non-null    float64
#  9   avg_trans          674 non-null    float64
#  10  avg_bal            674 non-null    float64
#  11  no_of_trans        674 non-null    int64
#  12  total_inhabitants  674 non-null    int64
#  13  avg_unemp_rt       674 non-null    float64
#  14  avg_crime_rt       674 non-null    float64
#  15  avg_salary         674 non-null    int64
# ...

# %%
berka.head(5)
# Out:
#    account_id  amount  duration  payments          frequency  date_diff  \
# 0           2   80952        24      3373  Monthly Statement        313
# 1         426  252060        60      4201  Monthly Statement        232
# 2         718   76944        12      6412  Monthly Statement        535
# 3        1603   78936        12      6578  Monthly Statement        273
# 4        1869   37944        36      1054  Monthly Statement        594
#
#   card_type  no_orders  avg_order  avg_trans   avg_bal  no_of_trans  \
# 0      none          2    5319.35    6593.05  36540.70          478
# 1      none          3    4194.73    6998.75  34002.08          444
# 2   classic          4    5075.25    9901.69  48722.66          281
# 3      none          3    3374.67    3259.68  30917.35          499
# 4   classic          1    1054.00    9041.93  67825.29          169
#
#    total_inhabitants  avg_unemp_rt  avg_crime_rt  avg_salary  age_at_loan  \
# ...

# %%
#create splits on the status column for the purposes of vizualizations:

# %%
berka_good = berka.loc[(berka['status']=='Good')]
berka_bad = berka.loc[(berka['status']=='Bad')]

# %%
berka_good.shape[0]
# Out:
# 600

# %%
berka_bad.shape[0]
# Out:
# 74

# %%
#Distribution of loan Amount across Good and Bad loans

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))
berka_good.amount.hist(bins=20, ax=ax1, label='Good', color='green', alpha=0.6)
berka_bad.amount.hist(bins=20, ax=ax2, label='bad', color='red', alpha=0.6)
ax1.set_title('Loan Amount')
ax2.set_title('Loan Amount')
ax1.legend()
ax2.legend()
plt.show()

# %%
#Duration in months across Good and Bad Loans

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))
berka_good.duration.hist(bins=20, ax=ax1, label='Good', color='green', alpha=0.6)
berka_bad.duration.hist(bins=20, ax=ax2, label='Bad', color='red', alpha=0.6)
ax1.set_title('Duration')
ax2.set_title('Duration')
ax1.legend()
ax2.legend()
plt.show()

# %%
#Distribution of monthly payment amount due for Good and Bad loans

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))
berka_good.payments.hist(bins=20, ax=ax1, label='Good', color='green', alpha=0.6)
berka_bad.payments.hist(bins=20, ax=ax2, label='Bad', color='red', alpha=0.6)
ax1.set_title('Payment Amount')
ax2.set_title('Payment Amount')
ax1.legend()
ax2.legend()
plt.show()

# %%
#Distribution of statement frequency per loan status

# %%
# frequency
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))
berka_good[['account_id', 'frequency']].groupby('frequency').count().plot(
    kind='bar', color='green', rot=30, ax=ax1, alpha=0.6, legend=False)
berka_bad[['account_id', 'frequency']].groupby('frequency').count().plot(
    kind='bar', color='red', rot=30, ax=ax2, alpha=0.6, legend=False)
plt.show()

# %%
#How many days after account open was loan taken for Good and Bad Loans

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))
berka_good.date_diff.hist(bins=20, ax=ax1, label='good', color='green', alpha=0.6)
berka_bad.date_diff.hist(bins=20, ax=ax2, label='bad', color='red', alpha=0.6)
plt.show()

# %%
#Distribution of credit card types across Good and Bad Loans (NAN = No card)

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))
berka_good[['account_id', 'card_type']].groupby('card_type').count().plot(
    kind='bar', color='green', rot=30, ax=ax1, alpha=0.6, legend=False)
berka_bad[['account_id', 'card_type']].groupby('card_type').count().plot(
    kind='bar', color='red', rot=30, ax=ax2, alpha=0.6, legend=False)
plt.show()

# %%
#Distribution of Number of Payment Orders the account hass

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))
berka_good.no_orders.hist(bins=20, ax=ax1, label='Good', color='green', alpha=0.6)
berka_bad.no_orders.hist(bins=20, ax=ax2, label='Bad', color='red', alpha=0.6)
ax1.legend()
ax2.legend()
plt.show()

# %%
#Average payment order split by loan status

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))
berka_good.avg_order.hist(bins=20, ax=ax1, label='Good', color='green', alpha=0.6)
berka_bad.avg_order.hist(bins=20, ax=ax2, label='Bad', color='red', alpha=0.6)
ax1.legend()
ax2.legend()
plt.show()

# %%
#Average transaction amount split by loan status

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))
berka_good.avg_trans.hist(bins=20, ax=ax1, label='Good', color='green', alpha=0.6)
berka_bad.avg_trans.hist(bins=20, ax=ax2, label='Bad', color='red', alpha=0.6)
ax1.legend()
ax2.legend()
plt.show()

# %%
#Average balance after transaction split by loan status

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))
berka_good.avg_bal.hist(bins=20, ax=ax1, label='Good', color='green', alpha=0.6)
berka_bad.avg_bal.hist(bins=20, ax=ax2, label='Bad', color='red', alpha=0.6)
ax1.legend()
ax2.legend()
plt.show()

# %%
#Number of transactions per accounts with loan - split by status

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))
berka_good.no_of_trans.hist(bins=20, ax=ax1, label='Good', color='green', alpha=0.6)
berka_bad.no_of_trans.hist(bins=20, ax=ax2, label='Bad', color='red', alpha=0.6)
ax1.legend()
ax2.legend()
plt.show()

# %%
#Total number of inhabitants in district of the loan

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))
berka_good.total_inhabitants.hist(bins=20, ax=ax1, label='Good', color='green', alpha=0.6)
berka_bad.total_inhabitants.hist(bins=20, ax=ax2, label='Bad', color='red', alpha=0.6)
ax1.legend()
ax2.legend()
plt.show()

# %%
#Average unemployment rate from the district of the loan

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))
berka_good.avg_unemp_rt.hist(bins=20, ax=ax1, label='Good', color='green', alpha=0.6)
berka_bad.avg_unemp_rt.hist(bins=20, ax=ax2, label='Bad', color='red', alpha=0.6)
ax1.legend()
ax2.legend()
plt.show()

# %%
#Avgerage crime rate in district of the loan

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))
berka_good.avg_crime_rt.hist(bins=20, ax=ax1, label='Good', color='green', alpha=0.6)
berka_bad.avg_crime_rt.hist(bins=20, ax=ax2, label='Bad', color='red', alpha=0.6)
ax1.legend()
ax2.legend()
plt.show()

# %%
#Average salary in the district the loan is from

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))
berka_good.avg_salary.hist(bins=20, ax=ax1, label='Good', color='green', alpha=0.6)
berka_bad.avg_salary.hist(bins=20, ax=ax2, label='Bad', color='red', alpha=0.6)
ax1.legend()
ax2.legend()
plt.show()

# %%
#Age of account owner at date of loan issuance

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))
berka_good.age_at_loan.hist(bins=20, ax=ax1, label='Good', color='green', alpha=0.6)
berka_bad.age_at_loan.hist(bins=20, ax=ax2, label='Bad', color='red', alpha=0.6)
ax1.legend()
ax2.legend()
plt.show()

# %%
#Distribution of gender based on loan status

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))
berka_good[['account_id', 'gender']].groupby('gender').count().plot(
    kind='bar', color='green', rot=30, ax=ax1, alpha=0.6, legend=False)
berka_bad[['account_id', 'gender']].groupby('gender').count().plot(
    kind='bar', color='red', rot=30, ax=ax2, alpha=0.6, legend=False)
plt.show()

# %%
#Shows the distribution of account owners that live in the same district as
#from where their loan was issued

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))
berka_good.same_district.hist(bins=20, ax=ax1, label='Good', color='green', alpha=0.6)
berka_bad.same_district.hist(bins=20, ax=ax2, label='Bad', color='red', alpha=0.6)
ax1.legend()
ax2.legend()
plt.show()

# %%
berka = berka.drop(labels='account_id', axis =1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-55-637bfa83b2dc> in <module>
# ----> 1 berka = berka.drop(labels='account_id', axis =1)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3988                 weight  1.0     0.8
#    3989         """
# -> 3990         return super().drop(
#    3991             labels=labels,
#    3992             axis=axis,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# ...

# %%
dfberka = berka.loc[:,['amount', 'duration', 'payments', 'date_diff','no_orders', 'avg_order', 'avg_trans', 'avg_bal','no_of_trans','total_inhabitants','avg_unemp_rt','avg_crime_rt','avg_salary','age_at_loan','gender','same_district','status']]

# %%
# Compute the correlation matrix
corr = dfberka.corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(17, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
corrMatrix = berka.corr()
sns.heatmap(corrMatrix, annot=True, linewidths=.5)
plt.show()

# %%
corr = berka.corr()

corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_efbf9971_9a95_11ec_b4fa_0022483caa37row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_efbf9971_9a95_11ec_b4fa_0022483caa37row0_col1 {
#             background-color:  #455cce;
#             color:  #f1f1f1;
#         }    #T_efbf9971_9a95_11ec_b4fa_0022483caa37row0_col2 {
#             background-color:  #5875e1;
#             color:  #000000;
#         }    #T_efbf9971_9a95_11ec_b4fa_0022483caa37row0_col3 {
#             background-color:  #465ecf;
#             color:  #f1f1f1;
#         }    #T_efbf9971_9a95_11ec_b4fa_0022483caa37row0_col4 {
#             background-color:  #3e51c5;
#             color:  #f1f1f1;
#         }    #T_efbf9971_9a95_11ec_b4fa_0022483caa37row0_col5 {
#             background-color:  #94b6ff;
#             color:  #000000;
#         }    #T_efbf9971_9a95_11ec_b4fa_0022483caa37row0_col6 {
#             background-color:  #8badfd;
#             color:  #000000;
# ...
